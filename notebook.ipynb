# %%
# !pip install BeautifulSoup4
import requests
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/cossieman2000/anaconda3/envs/first_lab/lib/python3.8/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/cossieman2000/anaconda3/envs/first_lab/lib/python3.8/site-packages (from BeautifulSoup4) (2.3.2.post1)

# %%
url = "https://yandex.ru/images/search?text=polar%20bear"
r = requests.get(url)
r.content
# Out:
# b'<!doctype html><html prefix="og: http://ogp.me/ns#"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1"><title data-react-helmet="true">\xd0\x9e\xd0\xb9!</title><meta data-react-helmet="true" property="og:title" content="\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81"><meta data-react-helmet="true" property="og:description" content="\xd0\x9d\xd0\xb0\xd0\xb9\xd0\xb4\xd1\x91\xd1\x82\xd1\x81\xd1\x8f \xd0\xb2\xd1\x81\xd1\x91"><meta data-react-helmet="true" property="og:image" content="https://yastatic.net/s3/home-static/_/37/37a02b5dc7a51abac55d8a5b6c865f0e.png"><link rel="stylesheet" href="/captcha_smart.5205103d27eb76a58bbb.min.css?k=1657871267302"><style>@media only screen and (min-width:651px){body{background-image:url(\'https://captcha-backgrounds.s3.yandex.net/static/default-background.jpg\')}}.LogoLink{background-image:url(\'data:image/svg+xml;base64,...\')}</style><div id="root"><div class="Theme Theme_color_yandex-default Theme_root_default"><div class="Container"><div class="Spacer" style="padding-bottom:40px"><a href="https://www.yandex.ru" title="Yandex" class="Link Link_view_default LogoLink"></a></div><form method="POST" action="/checkcaptcha?key=e312c526-be260ba3-168c7a2c-ee05a161_2%2F1663782413%2Fee781dccbc2f821fa60ffd48214bae87_66e13276245cddc29061bb91662c0513&retpath=aHR0cHM6Ly95YW5kZXgucnUvaW1hZ2VzL3NlYXJjaD90ZXh0PXBvbGFyJTIwYmVhcg%2C%2C_260ebbb3269a2378662d04810e5fd03d&u=164dae7e-43215a9f-641f346b-695d57b8"><div class="Spacer" style="padding-bottom:16px"><span class="Text Text_weight_medium Text_typography_headline-s">\xd0\x9f\xd0\xbe\xd0\xb4\xd1\x82\xd0\xb2\xd0\xb5\xd1\x80\xd0\xb4\xd0\xb8\xd1\x82\xd0\xb5, \xd1\x87\xd1\x82\xd0\xbe \xd0\xb7\xd0\xb0\xd0\xbf\xd1\x80\xd0\xbe\xd1\x81\xd1\x8b \xd0\xbe\xd1\x82\xd0\xbf\xd1\x80\xd0\xb0\xd0\xb2\xd0\xbb\xd1\x8f\xd0\xbb\xd0\xb8 \xd0\xb2\xd1\x8b, \xd0\xb0 \xd0\xbd\xd0\xb5 \xd1\x80\xd0\xbe\xd0\xb1\xd0\xbe\xd1\x82</span></div><span class="Text Text_weight_regular Text_typography_body-long-m">\xd0\x9d\xd0\xb0\xd0\xbc \xd0\xbe\xd1\x87\xd0\xb5\xd0\xbd\xd1\x8c \xd0\xb6\xd0\xb0\xd0\xbb\xd1\x8c, \xd0\xbd\xd0\xbe \xd0\xb7\xd0\xb0\xd0\xbf\xd1\x80\xd0\xbe\xd1\x81\xd1\x8b \xd1\x81 \xd0\xb2\xd0\xb0\xd1\x88\xd0\xb5\xd0\xb3\xd0\xbe \xd1\x83\xd1\x81\xd1\x82\xd1\x80\xd0\xbe\xd0\xb9\xd1\x81\xd1\x82\xd0\xb2\xd0\xb0 \xd0\xbf\xd0\xbe\xd1\x85\xd0\xbe\xd0\xb6\xd0\xb8 \xd0\xbd\xd0\xb0 \xd0\xb0\xd0\xb2\xd1\x82\xd0\xbe\xd0\xbc\xd0\xb0\xd1\x82\xd0\xb8\xd1\x87\xd0\xb5\xd1\x81\xd0\xba\xd0\xb8\xd0\xb5.\xc2\xa0<a href="https://yandex.ru/support/smart-captcha?unique_key=164dae7e-43215a9f-641f346b-695d57b8" class="Link Link_view_default">\xd0\x9f\xd0\xbe\xd1\x87\xd0\xb5\xd0\xbc\xd1\x83 \xd1\x8d\xd1\x82\xd0\xbe \xd0\xbc\xd0\xbe\xd0\xb3\xd0\xbb\xd0\xbe \xd0\xbf\xd1\x80\xd0\xbe\xd0\xb8\xd0\xb7\xd0\xbe\xd0\xb9\xd1\x82\xd0\xb8?</a></span><div class="Spacer Spacer_auto-gap_bottom" style="padding-top:40px;padding-bottom:40px"><div class="CheckboxCaptcha" data-testid="checkbox-captcha"><div class="CheckboxCaptcha-Inner"><div class="CheckboxCaptcha-Anchor"><input type="submit" class="CheckboxCaptcha-Button" aria-checked="false" aria-labelledby="smartcaptcha-status" role="checkbox"><div class="CheckboxCaptcha-Checkbox" data-checked="false"><svg class="SvgIcon" width="24" height="24" viewBox="0 0 24 25" fill="none"><path d="M4 12.5L9.5 18.5L20 6.5" stroke="#000" stroke-width="3" stroke-linecap="round" stroke-linejoin="round"></path></svg></div></div><div class="CheckboxCaptcha-Label"><span class="Text Text_weight_regular Text_typography_control-xxl CheckboxCaptcha-LabelText">\xd0\xaf \xd0\xbd\xd0\xb5 \xd1\x80\xd0\xbe\xd0\xb1\xd0\xbe\xd1\x82</span><span class="Text Text_color_control-secondary Text_weight_regular Text_typography_control-l">\xd0\x9d\xd0\xb0\xd0\xb6\xd0\xbc\xd0\xb8\xd1\x82\xd0\xb5, \xd1\x87\xd1\x82\xd0\xbe\xd0\xb1\xd1\x8b \xd0\xbf\xd1\x80\xd0\xbe\xd0\xb4\xd0\xbe\xd0\xbb\xd0\xb6\xd0\xb8\xd1\x82\xd1\x8c</span><sp ...

# %%
soup = BeautifulSoup(r.content, 'html')
soup
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#"><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1" name="viewport"/><title data-react-helmet="true">Ой!</title><meta content="Яндекс" data-react-helmet="true" property="og:title"/><meta content="Найдётся всё" data-react-helmet="true" property="og:description"/><meta content="https://yastatic.net/s3/home-static/_/37/37a02b5dc7a51abac55d8a5b6c865f0e.png" data-react-helmet="true" property="og:image"/><link href="/captcha_smart.5205103d27eb76a58bbb.min.css?k=1657871267302" rel="stylesheet"/><style>@media only screen and (min-width:651px){body{background-image:url('https://captcha-backgrounds.s3.yandex.net/static/default-background.jpg')}}.LogoLink{background-image:url('data:image/svg+xml;base64,...')}</style><div id="root"><div class="Theme Theme_color_yandex-default Theme_root_default"><div class="Container"><div class="Spacer" style="padding-bottom:40px"><a class="Link Link_view_default LogoLink" href="https://www.yandex.ru" title="Yandex"></a></div><form action="/checkcaptcha?key=e312c526-be260ba3-168c7a2c-ee05a161_2%2F1663782413%2Fee781dccbc2f821fa60ffd48214bae87_66e13276245cddc29061bb91662c0513&amp;retpath=aHR0cHM6Ly95YW5kZXgucnUvaW1hZ2VzL3NlYXJjaD90ZXh0PXBvbGFyJTIwYmVhcg%2C%2C_260ebbb3269a2378662d04810e5fd03d&amp;u=164dae7e-43215a9f-641f346b-695d57b8" method="POST"><div class="Spacer" style="padding-bottom:16px"><span class="Text Text_weight_medium Text_typography_headline-s">Подтвердите, что запросы отправляли вы, а не робот</span></div><span class="Text Text_weight_regular Text_typography_body-long-m">Нам очень жаль, но запросы с вашего устройства похожи на автоматические. <a class="Link Link_view_default" href="https://yandex.ru/support/smart-captcha?unique_key=164dae7e-43215a9f-641f346b-695d57b8">Почему это могло произойти?</a></span><div class="Spacer Spacer_auto-gap_bottom" style="padding-top:40px;padding-bottom:40px"><div class="CheckboxCaptcha" data-testid="checkbox-captcha"><div class="CheckboxCaptcha-Inner"><div class="CheckboxCaptcha-Anchor"><input aria-checked="false" aria-labelledby="smartcaptcha-status" class="CheckboxCaptcha-Button" role="checkbox" type="submit"/><div class="CheckboxCaptcha-Checkbox" data-checked="false"><svg class="SvgIcon" fill="none" height="24" viewbox="0 0 24 25" width="24"><path d="M4 12.5L9.5 18.5L20 6.5" stroke="#000" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path></svg></div></div><div class="CheckboxCaptcha-Label"><span class="Text Text_weight_regular Text_typography_control-xxl CheckboxCaptcha-LabelText">Я не робот</span><span class="Text Text_color_control-secondary Text_weight_regular Text_typography_control-l">Нажмите, чтобы продолжить</span><span class="Text Text_color_ghost Text_weight_regular Text_typography_control-s CheckboxCaptcha-Link"><a aria-describedby="connect-link-description" class="Link Link_view_captcha" href="https://cloud.yandex.ru/docs/smartcaptcha/" target="_blank">Подробнее</a><div class="visuallyhidden" id="connect-link-description">Сайт с информацией о проекте SmartCaptcha</div></span></div><div class="CheckboxCaptcha-Status visuallyhidden" id="smartcaptcha-status">SmartCaptcha нужна проверка пользователя</div></div></div></div><span class="Text Text_color_ghost Text_weight_regular Text_typography_control-xs">Если у вас возникли проблемы, пожалуйста, воспользуйтесь <a class="Link Link_view_default" href="https://yandex.ru/support/smart-captcha?unique_key=164dae7e-43215a9f-641f346b-695d57b8#help">формой обратной связи</a></span><input name="rdata" type="hidden"/><input name="aesKey" type="hidden"/><input name="signKey" type="hidden"/></form></div></div></div> <script>window.__SSR_DATA__={url:"/ru/checkbox",reqId:"1663782413406185-9060447359990644486-vla1-0276-vla-l7-balancer-8080-BAL",uniqueKey:"164dae7e-43215a9f-641f346b-695d57b8",invalid:"no",formAction:"/checkcaptcha?key=e312c526-be260ba3-168c7a2c-ee05a161_2%2F1663782413 ...

# %%
import time ## скачивание белых медведей, ошибка безопасного подключения
blocks = soup.findAll('div', class_='serp-item__preview')#нашли одну картинку
number = 0
for block in blocks:
    if (block):
        download_link = block.find('a', class_='serp-item__link').get('href')
        
        final_link = (download_link.split('=')[2])
        final_link1 = final_link.replace('%3A', ':')
        final_link2 = final_link1.replace('%2F', '/')
        final_link3 = (final_link2.split('&')[0])
        print(final_link3)
        try:
            print('1')
            image_bytes = requests.get(f'{final_link3}').content
            time.sleep(1)
            with open(f'/home/cossieman2000/WORK/python/dataset/polar bear/{number}.jpg', 'wb') as file:
                file.write(image_bytes)
            number += 1
            print(number)
        except:
            continue

# %%
import os
import requests
from bs4 import BeautifulSoup
import time
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/cossieman2000/anaconda3/envs/first_lab/lib/python3.8/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/cossieman2000/anaconda3/envs/first_lab/lib/python3.8/site-packages (from BeautifulSoup4) (2.3.2.post1)

# %%
path = '/home/cossieman2000/WORK/python/'
project_name = 'dataset'
folders = ['polar bear', 'brown bear']

def createFolder(path):
    if not os.path.exists(path):
        os.mkdir(path)

fullpath = os.path.join(path, project_name)
print(fullpath)
createFolder(fullpath)

for f in folders:
    folder = os.path.join(fullpath, f)
    print(folder)
    createFolder(folder)
# Out:
# /home/cossieman2000/WORK/python/dataset
# /home/cossieman2000/WORK/python/dataset/polar bear
# /home/cossieman2000/WORK/python/dataset/brown bear

# %%
p = 0
page = 0
for p in range (0, 60):
    url = "https://yandex.ru/images/search?p=0&text=polar%20bear"
    r = requests.get(url)
    print(url)
    r.content
    soup = BeautifulSoup(r.content, 'html')
    soup.text
    blocks = soup.findAll('div', class_='serp-item__preview')#нашли одну картинку
    number = 0
    print('a')
    for block in blocks:
        if (block):
            download_link = block.find('a', class_='serp-item__link').get('href')
            print('b')
            final_link = (download_link.split('=')[2])
            final_link1 = final_link.replace('%3A', ':')
            final_link2 = final_link1.replace('%2F', '/')
            final_link3 = (final_link2.split('&')[0])
            print(final_link3)
            try:
                image_bytes = requests.get(f'{final_link3}').content
                time.sleep(1)
                with open(f'/home/cossieman2000/WORK/python/dataset/' + folder + '/{number}.jpg', 'wb') as file:
                    file.write(image_bytes)
                number += 1
                print(number)
            except:
                continue
    #page += 1
# Out:
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a

# %%
url = "https://yandex.ru/images/search?p=0&text=polar%20bear"
r = requests.get(url)
print(url)
r.content
soup = BeautifulSoup(r.content, 'html')
blocks = soup.findAll('div', class_='serp-item__preview')#нашли одну картинку
number = 0
print('a')
for block in blocks:
    if (block):
        download_link = block.find('a', class_='serp-item__link').get('href')
        print('b')
        final_link = (download_link.split('=')[2])
        final_link1 = final_link.replace('%3A', ':')
        final_link2 = final_link1.replace('%2F', '/')
        final_link3 = (final_link2.split('&')[0])
        print(final_link3)
        try:
            image_bytes = requests.get(f'{final_link3}').content
            time.sleep(1)
            with open(f'/home/cossieman2000/WORK/python/dataset/' + folder + '/{number}.jpg', 'wb') as file:
                file.write(image_bytes)
            number += 1
            print(number)
        except:
            continue
# Out:
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a

# %%
page = 0
url1 = "https://yandex.ru/images/search?p=" + str(page) +"&text=polar%20bear"
url2 = "https://yandex.ru/images/search?p=" + str(page) +"&text=brown%20bear"

# %%
page = 0
for p in range(0, 37):
    dowload_images(url1, folders[1])
    print(page)
    print(p)
    page +=1
# Out:
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 0
# 0
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 1
# 1
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 2
# 2
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 3
# 3
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 4
# 4
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 5
# 5
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 6
# 6
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 7
# 7
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 8
# 8
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 9
# 9
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 10
# 10
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 11
# 11
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 12
# 12
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 13
# 13
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 14
# 14
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 15
# 15
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 16
# 16
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 17
# 17
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 18
# 18
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 19
# 19
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 20
# 20
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 21
# 21
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 22
# 22
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 23
# 23
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 24
# 24
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 25
# 25
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 26
# 26
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 27
# 27
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 28
# 28
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 29
# 29
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# b
# 0
# 30
# 30

# %%
page = 0
for p in range(0,50):
    url1 = "https://yandex.ru/images/search?p=" + str(p) +"&text=polar%20bear"
    r = requests.get(url1)
    print(url1)
    r.content
    soup = BeautifulSoup(r.content, 'html')
    print('a')
    blocks = soup.findAll('div', class_='serp-item__preview')#нашли одну картинку
    number = 0
    print('b')
    for block in blocks:
        print('c')
        if (block):
            download_link = block.find('a', class_='serp-item__link').get('href')
            print('b')
            final_link = (download_link.split('=')[2])
            final_link1 = final_link.replace('%3A', ':')
            final_link2 = final_link1.replace('%2F', '/')
            final_link3 = (final_link2.split('&')[0])
            print(final_link3)
            try:
                image_bytes = requests.get(f'{final_link3}').content
                time.sleep(1)
                with open(f'/home/cossieman2000/WORK/python/dataset/polar bear/{number}.jpg', 'wb') as file:
                    file.write(image_bytes)
                number += 1
                print(number)
            except:
                continue
    page +=1
# Out:
# https://yandex.ru/images/search?p=0&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=1&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=2&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=3&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=4&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=5&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=6&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=7&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=8&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=9&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=10&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=11&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=12&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=13&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=14&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=15&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=16&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=17&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=18&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=19&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=20&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=21&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=22&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=23&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=24&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=25&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=26&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=27&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=28&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=29&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=30&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=31&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=32&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=33&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=34&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=35&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=36&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=37&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=38&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=39&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=40&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=41&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=42&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=43&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=44&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=45&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=46&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=47&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=48&text=polar%20bear
# a
# b
# https://yandex.ru/images/search?p=49&text=polar%20bear
# a
# b

# %%
url1 = "https://yandex.ru/images/search?text=polar%20bear"
r = requests.get(url1)
print(url1)
r.content
soup = BeautifulSoup(r.content, 'html')
print('a')
blocks = soup.find_all('div', class_='serp-item__preview')#нашли одну картинку
number = 0
print('b')
for block in blocks:
        print('c')
        if (block):
            download_link = block.find('a', class_='serp-item__link').get('href')
            print('b')
            final_link = (download_link.split('=')[2])
            final_link1 = final_link.replace('%3A', ':')
            final_link2 = final_link1.replace('%2F', '/')
            final_link3 = (final_link2.split('&')[0])
            print(final_link3)
            try:
                image_bytes = requests.get(f'{final_link3}').content
                time.sleep(1)
                with open(f'/home/cossieman2000/WORK/python/dataset/polar bear/{number}.jpg', 'wb') as file:
                    file.write(image_bytes)
                number += 1
                print(number)
            except:
                continue
# Out:
# https://yandex.ru/images/search?text=polar%20bear
# a
# b
